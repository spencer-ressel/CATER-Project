# %% [markdown]
# # Documentation

# %% [markdown]
# This is a set of auxiliary functions useful for downloading, organizing, and compiling CMIP6 data

# %% [markdown]
# # Imports

# %%
import os
import glob
import sys
import xarray as xr

# %% [markdown]
# # Move files from Misc Data to correct folders

# %%
models = [
    'ACCESS-CM2',
    'ACCESS-ESM1-5',
    'BCC-CSM2-MR', 
    'CanESM5',
    'CNRM-CM6-1',
    'HadGEM3-GC31-LL',
    'IPSL-CM6A-LR',
    'MIROC6',
    'MRI-ESM2-0',
    'NorESM2-LM'
]
experiments = ['hist-GHG', 'hist-nat', 'historical', 'ssp245']
variables = ['zg']

# os.chdir("/home/disk/tc/pangulo/CMIP6/Misc Data/")

for model in models:
    print(f"{model} \n=============================================================")
    for exp in experiments:
        for variable in variables:
            os.chdir(f"/home/disk/tc/pangulo/CMIP6/{model}/{exp}/")
            files = glob.glob(f"zg_Amon_{model}_{exp}_*.nc")
            
            if not files:
                print(f"{model}/{exp}/ has no subfiles for {variable}")
                pass
            
            else:
                for file in files:
                    # os.system(f"mv {file} /home/disk/tc/pangulo/CMIP6/{model}/{exp}")
                    # print(f"mv {file} /home/disk/tc/pangulo/CMIP6/{model}/{exp}")
                    
                    os.system(f"mv {file} subfiles/")
                    print(f"mv {file} subfiles/")
                    
    print("=============================================================")
print("all files moved")
# Out:
# ACCESS-CM2
# =============================================================
# ACCESS-CM2/hist-GHG/ has no subfiles for zg
# ACCESS-CM2/hist-nat/ has no subfiles for zg
# ACCESS-CM2/historical/ has no subfiles for zg
# ACCESS-CM2/ssp245/ has no subfiles for zg
# =============================================================
# ACCESS-ESM1-5
# =============================================================
# ACCESS-ESM1-5/hist-GHG/ has no subfiles for zg
# ACCESS-ESM1-5/hist-nat/ has no subfiles for zg
# ACCESS-ESM1-5/historical/ has no subfiles for zg
# ACCESS-ESM1-5/ssp245/ has no subfiles for zg
# =============================================================
# BCC-CSM2-MR
# =============================================================
# BCC-CSM2-MR/hist-GHG/ has no subfiles for zg
# BCC-CSM2-MR/hist-nat/ has no subfiles for zg
# BCC-CSM2-MR/historical/ has no subfiles for zg
# BCC-CSM2-MR/ssp245/ has no subfiles for zg
# =============================================================
# CanESM5
# =============================================================
# CanESM5/hist-GHG/ has no subfiles for zg
# CanESM5/hist-nat/ has no subfiles for zg
# CanESM5/historical/ has no subfiles for zg
# CanESM5/ssp245/ has no subfiles for zg
# =============================================================
# CNRM-CM6-1
# =============================================================
# CNRM-CM6-1/hist-GHG/ has no subfiles for zg
# CNRM-CM6-1/hist-nat/ has no subfiles for zg
# CNRM-CM6-1/historical/ has no subfiles for zg
# CNRM-CM6-1/ssp245/ has no subfiles for zg
# =============================================================
# HadGEM3-GC31-LL
# =============================================================
# HadGEM3-GC31-LL/hist-GHG/ has no subfiles for zg
# HadGEM3-GC31-LL/hist-nat/ has no subfiles for zg
# HadGEM3-GC31-LL/historical/ has no subfiles for zg
# HadGEM3-GC31-LL/ssp245/ has no subfiles for zg
# =============================================================
# IPSL-CM6A-LR
# =============================================================
# IPSL-CM6A-LR/hist-GHG/ has no subfiles for zg
# IPSL-CM6A-LR/hist-nat/ has no subfiles for zg
# IPSL-CM6A-LR/historical/ has no subfiles for zg
# IPSL-CM6A-LR/ssp245/ has no subfiles for zg
# =============================================================
# MIROC6
# =============================================================
# MIROC6/hist-GHG/ has no subfiles for zg
# MIROC6/hist-nat/ has no subfiles for zg
# MIROC6/historical/ has no subfiles for zg
# MIROC6/ssp245/ has no subfiles for zg
# =============================================================
# MRI-ESM2-0
# =============================================================
# MRI-ESM2-0/hist-GHG/ has no subfiles for zg
# MRI-ESM2-0/hist-nat/ has no subfiles for zg
# MRI-ESM2-0/historical/ has no subfiles for zg
# MRI-ESM2-0/ssp245/ has no subfiles for zg
# =============================================================
# NorESM2-LM
# =============================================================
# NorESM2-LM/hist-GHG/ has no subfiles for zg
# NorESM2-LM/hist-nat/ has no subfiles for zg
# NorESM2-LM/historical/ has no subfiles for zg
# NorESM2-LM/ssp245/ has no subfiles for zg
# =============================================================
# all files moved

# %% [markdown]
# # Compile subfiles

# %%
models = [
    'ACCESS-CM2',
    'ACCESS-ESM1-5',
    'BCC-CSM2-MR', 
    'CanESM5',
    'CNRM-CM6-1',
    'HadGEM3-GC31-LL',
    'IPSL-CM6A-LR',
    'MIROC6',
    'MRI-ESM2-0',
    'NorESM2-LM'
]
experiments = ['hist-GHG', 'hist-nat', 'historical', 'ssp245']
# variables = ['rlut', 'tasmax', 'tos']
variables = ['zg']
# variants = ['r1i1p1f1']

for model in models:
    print(f"{model} \n=============================================================")
    for exp in experiments:
        for variable in variables:
            
            file_directory = f"/home/disk/tc/pangulo/CMIP6/{model}/{exp}/"
            os.chdir(file_directory)
            
            # Search for an already compiled file
            compiled_file = glob.glob(f"compiled_{variable}*.nc")
            
            # If it exists, skip this variable
            if compiled_file:
                print(f"{model} {exp} {variable} already compiled")
                
            # Otherwise grab all subfiles of that variable
            else:
                uncompiled_files = sorted(glob.glob(f"{variable}*.nc"))

                # If there are none, skip
                if not uncompiled_files:
                    print(f"No file for {model} {exp} {variable} {variant}")
                    continue

                # Create a folder called subfiles if it doesn't exist
                else:
                    if not os.path.exists(f"./subfiles/"):
                        os.system("mkdir subfiles/")
                    else:
                        pass                                    
                
                # For each set of files, get the correct initial and final dates
                [_, freq, _, _, variant, grid, period] = uncompiled_files[0].split("_")
                starting_date = period.split("-")[0]
                [_, freq, _, _, variant, grid, period] = uncompiled_files[-1].split("_")
                ending_date = period.split("-")[-1].split(".")[0]

                # Compile the files using the cdo mergetime command
                compiled_file = f"compiled_{variable}_{freq}_{model}_{exp}_{variant}_{grid}_{starting_date}-{ending_date}.nc"
                merge_command = f"cdo mergetime {variable}_{freq}_{model}_{exp}_{variant}*.nc {compiled_file}"

                if os.path.exists(compiled_file):
                    continue
                else:
                    os.system(merge_command)
                    print(merge_command)


    print(f"=============================================================")
print('done')
# Out:
# ACCESS-CM2
# =============================================================
# ACCESS-CM2 hist-GHG zg already compiled
# ACCESS-CM2 hist-nat zg already compiled
# ACCESS-CM2 historical zg already compiled
# ACCESS-CM2 ssp245 zg already compiled
# =============================================================
# ACCESS-ESM1-5
# =============================================================
# ACCESS-ESM1-5 hist-GHG zg already compiled
# ACCESS-ESM1-5 hist-nat zg already compiled
# ACCESS-ESM1-5 historical zg already compiled
# ACCESS-ESM1-5 ssp245 zg already compiled
# =============================================================
# BCC-CSM2-MR
# =============================================================
# BCC-CSM2-MR hist-GHG zg already compiled
# BCC-CSM2-MR hist-nat zg already compiled
# BCC-CSM2-MR historical zg already compiled
# BCC-CSM2-MR ssp245 zg already compiled
# =============================================================
# CanESM5
# =============================================================
# CanESM5 hist-GHG zg already compiled
# CanESM5 hist-nat zg already compiled
# CanESM5 historical zg already compiled
# CanESM5 ssp245 zg already compiled
# =============================================================
# CNRM-CM6-1
# =============================================================
# CNRM-CM6-1 hist-GHG zg already compiled
# CNRM-CM6-1 hist-nat zg already compiled
# CNRM-CM6-1 historical zg already compiled
# CNRM-CM6-1 ssp245 zg already compiled
# =============================================================
# HadGEM3-GC31-LL
# =============================================================
# HadGEM3-GC31-LL hist-GHG zg already compiled
# HadGEM3-GC31-LL hist-nat zg already compiled
# HadGEM3-GC31-LL historical zg already compiled
# HadGEM3-GC31-LL ssp245 zg already compiled
# =============================================================
# IPSL-CM6A-LR
# =============================================================
# IPSL-CM6A-LR hist-GHG zg already compiled
# IPSL-CM6A-LR hist-nat zg already compiled
# IPSL-CM6A-LR historical zg already compiled
# IPSL-CM6A-LR ssp245 zg already compiled
# =============================================================
# MIROC6
# =============================================================
# MIROC6 hist-GHG zg already compiled
# MIROC6 hist-nat zg already compiled
# MIROC6 historical zg already compiled
# MIROC6 ssp245 zg already compiled
# =============================================================
# MRI-ESM2-0
# =============================================================
# MRI-ESM2-0 hist-GHG zg already compiled
# MRI-ESM2-0 hist-nat zg already compiled
# MRI-ESM2-0 historical zg already compiled
# MRI-ESM2-0 ssp245 zg already compiled
# =============================================================
# NorESM2-LM
# =============================================================
# NorESM2-LM hist-GHG zg already compiled
# NorESM2-LM hist-nat zg already compiled
# NorESM2-LM historical zg already compiled
# NorESM2-LM ssp245 zg already compiled
# =============================================================
# done

# %% [markdown]
# # Show .sh files

# %%
models = [
    'ACCESS-CM2',
    'ACCESS-ESM1-5',
    'BCC-CSM2-MR', 
    'CanESM5',
    'CNRM-CM6-1',
    'HadGEM3-GC31-LL',
    'IPSL-CM6A-LR',
    'MIROC6',
    'MRI-ESM2-0',
    'NorESM2-LM'
]
experiments = ['hist-GHG', 'hist-nat', 'historical', 'ssp245']
# variables = ['rlut', 'tasmax', 'tos']
variables = ['zg']
# variants = ['r1i1p1f1']

for model in models:
    print(f"{model} \n=============================================================")
    for exp in experiments:
        os.chdir(f"/home/disk/tc/pangulo/CMIP6/{model}/{exp}/")
        sh_files = glob.glob(f"*.sh")
        
        if not sh_files:
            print(f"No sh files for {model}/{exp}")
            pass
        
        else:
            for file in sh_files:
                print(f"{model}/{exp}: {file}")
             
    print("=============================================================")
print("done")
# Out:
# ACCESS-CM2
# =============================================================
# No sh files for ACCESS-CM2/hist-GHG
# ACCESS-CM2/hist-nat: wget_script_2023-9-14_14-56-47.sh
# ACCESS-CM2/historical: wget_script_2023-9-14_15-7-46.sh
# No sh files for ACCESS-CM2/ssp245
# =============================================================
# ACCESS-ESM1-5
# =============================================================
# ACCESS-ESM1-5/hist-GHG: CMIP6.DAMIP.CSIRO.ACCESS-ESM1-5.hist-GHG.r1i1p1f1.Amon.rlut.gn.sh
# ACCESS-ESM1-5/hist-nat: CMIP6.DAMIP.CSIRO.ACCESS-ESM1-5.hist-nat.r1i1p1f1.Amon.rlut.gn.sh
# ACCESS-ESM1-5/hist-nat: wget_script_2023-9-19_14-9-6.sh
# ACCESS-ESM1-5/historical: wget_script_2023-9-14_14-58-1.sh
# ACCESS-ESM1-5/historical: CMIP6.CMIP.CSIRO.ACCESS-ESM1-5.historical.r1i1p1f1.Amon.rlut.gn.sh
# ACCESS-ESM1-5/ssp245: CMIP6.ScenarioMIP.CSIRO.ACCESS-ESM1-5.ssp245.r1i1p1f1.Amon.rlut.gn.sh
# =============================================================
# BCC-CSM2-MR
# =============================================================
# BCC-CSM2-MR/hist-GHG: CMIP6.DAMIP.BCC.BCC-CSM2-MR.hist-GHG.r1i1p1f1.day.tasmax.gn.sh
# BCC-CSM2-MR/hist-GHG: CMIP6.DAMIP.BCC.BCC-CSM2-MR.hist-GHG.r1i1p1f1.Amon.rlut.gn.sh
# BCC-CSM2-MR/hist-GHG: CMIP6.DAMIP.BCC.BCC-CSM2-MR.hist-GHG.r1i1p1f1.Omon.tos.gn.sh
# BCC-CSM2-MR/hist-nat: CMIP6.DAMIP.BCC.BCC-CSM2-MR.hist-nat.r1i1p1f1.Omon.tos.gn.sh
# BCC-CSM2-MR/hist-nat: CMIP6.DAMIP.BCC.BCC-CSM2-MR.hist-nat.r1i1p1f1.Amon.rlut.gn.sh
# BCC-CSM2-MR/hist-nat: CMIP6.DAMIP.BCC.BCC-CSM2-MR.hist-nat.r1i1p1f1.day.tasmax.gn.sh
# BCC-CSM2-MR/historical: CMIP6.CMIP.BCC.BCC-CSM2-MR.historical.r1i1p1f1.Amon.rlut.gn.sh
# BCC-CSM2-MR/historical: CMIP6.CMIP.BCC.BCC-CSM2-MR.historical.r1i1p1f1.day.tasmax.gn.sh
# BCC-CSM2-MR/historical: CMIP6.CMIP.BCC.BCC-CSM2-MR.historical.r1i1p1f1.Omon.tos.gn.sh
# BCC-CSM2-MR/ssp245: CMIP6.ScenarioMIP.BCC.BCC-CSM2-MR.ssp245.r1i1p1f1.day.tasmax.gn.sh
# BCC-CSM2-MR/ssp245: CMIP6.ScenarioMIP.BCC.BCC-CSM2-MR.ssp245.r1i1p1f1.Amon.rlut.gn.sh
# BCC-CSM2-MR/ssp245: CMIP6.ScenarioMIP.BCC.BCC-CSM2-MR.ssp245.r1i1p1f1.Omon.tos.gn.sh
# =============================================================
# CanESM5
# =============================================================
# CanESM5/hist-GHG: CMIP6.DAMIP.CCCma.CanESM5.hist-GHG.r1i1p1f1.Amon.rlut.gn.sh
# CanESM5/hist-nat: CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r1i1p1f1.Amon.rlut.gn.sh
# CanESM5/hist-nat: wget-20230914100114.sh
# CanESM5/historical: CMIP6.CMIP.CCCma.CanESM5.historical.r1i1p1f1.Amon.rlut.gn.sh
# CanESM5/ssp245: CMIP6.ScenarioMIP.CCCma.CanESM5.ssp245.r1i1p1f1.Amon.rlut.gn.sh
# =============================================================
# CNRM-CM6-1
# =============================================================
# CNRM-CM6-1/hist-GHG: CMIP6.DAMIP.CNRM-CERFACS.CNRM-CM6-1.hist-GHG.r1i1p1f2.Omon.tos.gr1.sh
# CNRM-CM6-1/hist-GHG: CMIP6.DAMIP.CNRM-CERFACS.CNRM-CM6-1.hist-GHG.r1i1p1f2.Amon.rlut.gr.sh
# CNRM-CM6-1/hist-GHG: CMIP6.DAMIP.CNRM-CERFACS.CNRM-CM6-1.hist-GHG.r1i1p1f2.day.tasmax.gr.sh
# CNRM-CM6-1/hist-nat: CMIP6.DAMIP.CNRM-CERFACS.CNRM-CM6-1.hist-nat.r1i1p1f2.Amon.rlut.gr.sh
# CNRM-CM6-1/historical: CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r1i1p1f2.Amon.rlut.gr.sh
# CNRM-CM6-1/historical: wget_script_2023-9-14_14-58-29.sh
# CNRM-CM6-1/ssp245: CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp245.r1i1p1f2.Amon.rlut.gr.sh
# CNRM-CM6-1/ssp245: wget_script_2023-9-19_14-33-36.sh
# =============================================================
# HadGEM3-GC31-LL
# =============================================================
# HadGEM3-GC31-LL/hist-GHG: CMIP6.DAMIP.MOHC.HadGEM3-GC31-LL.hist-GHG.r1i1p1f3.Omon.tos.gn.sh
# HadGEM3-GC31-LL/hist-GHG: CMIP6.DAMIP.MOHC.HadGEM3-GC31-LL.hist-GHG.r1i1p1f3.day.tasmax.gn.sh
# HadGEM3-GC31-LL/hist-GHG: CMIP6.DAMIP.MOHC.HadGEM3-GC31-LL.hist-GHG.r1i1p1f3.Amon.rlut.gn.sh
# HadGEM3-GC31-LL/hist-GHG: wget-20230914173243.sh
# HadGEM3-GC31-LL/hist-nat: CMIP6.DAMIP.MOHC.HadGEM3-GC31-LL.hist-nat.r1i1p1f3.Amon.rlut.gn.sh
# HadGEM3-GC31-LL/hist-nat: wget_script_2023-9-19_14-15-21.sh
# HadGEM3-GC31-LL/historical: CMIP6.CMIP.MOHC.HadGEM3-GC31-LL.historical.r1i1p1f3.Amon.rlut.gn.sh
# HadGEM3-GC31-LL/historical: wget_script_2023-9-14_14-58-51.sh
# HadGEM3-GC31-LL/ssp245: CMIP6.ScenarioMIP.MOHC.HadGEM3-GC31-LL.ssp245.r1i1p1f3.Amon.rlut.gn.sh
# HadGEM3-GC31-LL/ssp245: wget_script_2023-9-19_14-34-13.sh
# =============================================================
# IPSL-CM6A-LR
# =============================================================
# IPSL-CM6A-LR/hist-GHG: CMIP6.DAMIP.IPSL.IPSL-CM6A-LR.hist-GHG.r1i1p1f1.Amon.rlut.gr.sh
# IPSL-CM6A-LR/hist-nat: CMIP6.DAMIP.IPSL.IPSL-CM6A-LR.hist-nat.r1i1p1f1.Amon.rlut.gr.sh
# IPSL-CM6A-LR/historical: CMIP6.CMIP.IPSL.IPSL-CM6A-LR.historical.r1i1p1f1.Amon.rlut.gr.sh
# IPSL-CM6A-LR/ssp245: CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp245.r1i1p1f1.Amon.rlut.gr.sh
# IPSL-CM6A-LR/ssp245: wget-20230601162713.sh
# =============================================================
# MIROC6
# =============================================================
# MIROC6/hist-GHG: CMIP6.DAMIP.MIROC.MIROC6.hist-GHG.r1i1p1f1.Amon.rlut.gn.sh
# MIROC6/hist-nat: CMIP6.DAMIP.MIROC.MIROC6.hist-nat.r1i1p1f1.Amon.rlut.gn.sh
# MIROC6/historical: wget-20230515140609.sh
# MIROC6/historical: CMIP6.CMIP.MIROC.MIROC6.historical.r1i1p1f1.Amon.rlut.gn.sh
# MIROC6/ssp245: CMIP6.ScenarioMIP.MIROC.MIROC6.ssp245.r1i1p1f1.Amon.rlut.gn.sh
# =============================================================
# MRI-ESM2-0
# =============================================================
# MRI-ESM2-0/hist-GHG: wget-20230516152048.sh
# MRI-ESM2-0/hist-GHG: CMIP6.DAMIP.MRI.MRI-ESM2-0.hist-GHG.r1i1p1f1.Amon.rlut.gn.sh
# MRI-ESM2-0/hist-nat: CMIP6.DAMIP.MRI.MRI-ESM2-0.hist-nat.r1i1p1f1.Amon.rlut.gn.sh
# MRI-ESM2-0/historical: CMIP6.CMIP.MRI.MRI-ESM2-0.historical.r1i1p1f1.Amon.rlut.gn.sh
# MRI-ESM2-0/ssp245: CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp245.r1i1p1f1.Amon.rlut.gn.sh
# =============================================================
# NorESM2-LM
# =============================================================
# No sh files for NorESM2-LM/hist-GHG
# NorESM2-LM/hist-nat: wget_script_2023-9-19_14-23-27.sh
# No sh files for NorESM2-LM/historical
# No sh files for NorESM2-LM/ssp245
# =============================================================
# done

# %% [markdown]
# # Extract a given height level from geopotential height data

# %%
models_list = [
    'ACCESS-CM2',
    'ACCESS-ESM1-5',
    'BCC-CSM2-MR', 
    'CanESM5',
    'CNRM-CM6-1',
    'HadGEM3-GC31-LL',
    'IPSL-CM6A-LR',
    'MIROC6',
    'MRI-ESM2-0',
    'NorESM2-LM'
]
experiments_list = ['hist-GHG', 'hist-nat', 'historical', 'ssp245']
variables = ['zg']

for model in models_list:
    for exp in experiments_list:
        os.chdir(f"/home/disk/tc/pangulo/CMIP6/{model}/{exp}")
        
        file = glob.glob(f"./compiled_zg_*.nc")[0]        
        [header, closer] = file.split("/")[-1].split("zg")
    
        zg_data = xr.open_dataset(file)
        zg200_data = zg_data.isel(plev=9)
        zg200_data.to_netcdf(f"{header}zg200{closer}")
